# %% [markdown]
# ### Python Submission

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# import the necessary library

# %% [markdown]
# ### Imported the data set into a Pandas DataFrame.

# %%
df=pd.read_csv(r'C:\Users\deole\Desktop\pythone submission\Movie Assignment Data.csv')
df
# Out:
#                                            Title  title_year     budget  \
# 0                                     La La Land        2016   30000000
# 1                                       Zootopia        2016  150000000
# 2                                           Lion        2016   12000000
# 3                                        Arrival        2016   47000000
# 4                          Manchester by the Sea        2016    9000000
# ..                                           ...         ...        ...
# 95                                      Whiplash        2014    3300000
# 96                               Before Midnight        2013    3000000
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
#
#         Gross              actor_1_name        actor_2_name  \
# ...

# %% [markdown]
# ### Q.2--> Generate descriptive statistics for the budget of all the movies.

# %%
#the describe function will help to analyze  & summarize the budget of all movies, such as max, min, avg, std etc.
df.budget.describe()
# Out:
# count    1.000000e+02
# mean     7.838400e+07
# std      7.445295e+07
# min      3.000000e+06
# 25%      1.575000e+07
# 50%      4.225000e+07
# 75%      1.500000e+08
# max      2.600000e+08
# Name: budget, dtype: float64

# %% [markdown]
# ### Q.3 --> Find out how many of the top-rated movies produced in the United States have a PG-13 rating.

# %%
df1=df[(df['Country']=='USA') & (df['content_rating']=='PG-13')]
#select only country with USA & content rating with PG-13
df1
# Out:
#                                          Title  title_year     budget  \
# 0                                   La La Land        2016   30000000
# 3                                      Arrival        2016   47000000
# 6                               Doctor Strange        2016  165000000
# 8                        The Dark Knight Rises        2012  250000000
# 9                   Captain America: Civil War        2016  250000000
# 10         The Hobbit: The Desolation of Smaug        2013  225000000
# 11                                The Avengers        2012  220000000
# 14                  X-Men: Days of Future Past        2014  200000000
# 15                     Star Trek Into Darkness        2013  190000000
# 16           The Hobbit: An Unexpected Journey        2012  180000000
# 17                            Edge of Tomorrow        2014  178000000
# 19                     Guardians of the Galaxy        2014  170000000
# ...

# %%
#to calculate the number of movies with country USA & content rating with PG-13 is 35
df1.count()
# Out:
# Title             35
# title_year        35
# budget            35
# Gross             35
# actor_1_name      35
#                   ..
# Votes1000         35
# VotesUS           35
# VotesnUS          35
# content_rating    35
# Country           35
# Length: 62, dtype: int64

# %% [markdown]
# ### Q4-->Find out whether any of the top-rated movies produced in 2014 were not produced in the United States.

# %%
(df['Country'] !='USA') & (df['title_year'] == 2014)
#filter out the country which is not USA and then filter the year equal to 2014
# df[(df['Country'] !='USA') & (df['title_year'] == 2014)] will result out as 4 movies
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
df2=df[(df['Country'] !='USA') & (df['title_year'] == 2014)]
df2.count()
# Out:
# Title             4
# title_year        4
# budget            4
# Gross             4
# actor_1_name      4
#                  ..
# Votes1000         4
# VotesUS           4
# VotesnUS          4
# content_rating    4
# Country           4
# Length: 62, dtype: int64

# %% [markdown]
# ### Q.5-->Find the percentage of the top-rated movies that are in: 1 genre only, 2 genre only, 3 genre only

# %%
#find out the notnull value by using notnull() function, then sum by axis=1
df403=df[['genre_1','genre_2','genre_3']].notnull().sum(axis=1)
(df403/3)*100
# Out:
# 0     100.000000
# 1     100.000000
# 2      66.666667
# 3     100.000000
# 4      33.333333
#          ...
# 95     66.666667
# 96     66.666667
# 97    100.000000
# 98    100.000000
# 99     66.666667
# Length: 100, dtype: float64

# %% [markdown]
# ### Q.6-->Convert the budget and gross values from “dollars” to “dollars in millions” for all top-rated movies. Round the converted values down to 3 decimal places. For example, a value of 192,345,273 should be converted to 192.345.

# %%
(df['budget']/10**6).round(3)
#filter budget column and then divide by 1o**6 and rounding off to 3 decimal
# Out:
# 0      30.0
# 1     150.0
# 2      12.0
# 3      47.0
# 4       9.0
#       ...
# 95      3.3
# 96      3.0
# 97    245.0
# 98    150.0
# 99      5.0
# Name: budget, Length: 100, dtype: float64

# %%
(df['Gross']/10**6).round(3)
#filter Gross column and then divide by 1o**6 and rounding off to 3 decimal
# Out:
# 0     151.102
# 1     341.268
# 2      51.739
# 3     100.546
# 4      47.695
#        ...
# 95     13.092
# 96      8.115
# 97    936.662
# 98    296.348
# 99      0.224
# Name: Gross, Length: 100, dtype: float64

# %% [markdown]
# ### Q.7--> List all details for the top 10 movies with the highest profit, sorted from highest to lowest. Hint: Profit is not a column in the DataFrame. You will need to calculate it.

# %%
df['Profit']=df['Gross']-df['budget']
df.head(10)
# Out:
#                         Title  title_year     budget      Gross  \
# 0                  La La Land        2016   30000000  151101803
# 1                    Zootopia        2016  150000000  341268248
# 2                        Lion        2016   12000000   51738905
# 3                     Arrival        2016   47000000  100546139
# 4       Manchester by the Sea        2016    9000000   47695371
# 5          Hell or High Water        2016   12000000   27007844
# 6              Doctor Strange        2016  165000000  232641920
# 7                     Tangled        2010  260000000  200807262
# 8       The Dark Knight Rises        2012  250000000  448130642
# 9  Captain America: Civil War        2016  250000000  407197282
#
#            actor_1_name        actor_2_name          actor_3_name  \
# 0          Ryan Gosling          Emma Stone            Amiée Conn
# 1      Ginnifer Goodwin       Jason Bateman            Idris Elba
# ...

# %%
df.sort_values(by='Profit',ascending= False).head(10)
# Out:
#                                          Title  title_year     budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015  245000000
# 11                                The Avengers        2012  220000000
# 47                                    Deadpool        2016   58000000
# 32             The Hunger Games: Catching Fire        2013  130000000
# 12                                 Toy Story 3        2010  200000000
# 8                        The Dark Knight Rises        2012  250000000
# 45                              The Lego Movie        2014   60000000
# 1                                     Zootopia        2016  150000000
# 41                               Despicable Me        2010   69000000
# 18                                  Inside Out        2015  175000000
#
#         Gross       actor_1_name       actor_2_name           actor_3_name  \
# 97  936662225        Doug Walker         Rob Walker                      0
# ...

# %% [markdown]
# ### Q.8-->Generate a list of all the actors, in alphabetical order by the first name, that have starred in a top-rated movie. If an actor has starred in multiple movies, their name should appear only once on the list. Assume that all actors’ names are in the format <first_name> <last_name>.

# %%
l1=list(df['actor_1_name'])
l2=list(df['actor_2_name'])
l3=list(df['actor_3_name'])
l4=np.vstack([l1,l2,l3])
l5=np.unique(l4)
list(np.sort(l5))
# Out:
# ['0',
#  'Abraham Benrubi',
#  'Adam Brown',
#  'Aidan Quinn',
#  'Aidan Turner',
#  'Albert Brooks',
#  'Albert Finney',
#  'Aldis Hodge',
#  'Alexandra Maria Lara',
#  'Alfred Enoch',
#  'Alison Brie',
#  'Allen Leech',
#  'America Ferrera',
#  'Amiée Conn',
#  'Amy Adams',
#  'Amy Poehler',
#  'Amy Ryan',
#  'Amy Warren',
#  'Andrew Garfield',
#  'Anna Kendrick',
#  'Anne Hathaway',
#  'Ariane Labed',
#  'Athina Rachel Tsangari',
#  'Ato Essandoh',
#  'Audrey Fleurot',
#  'Basher Savage',
#  'Ben Foster',
#  'Benedict Cumberbatch',
#  'Benedict Wong',
#  'Bernardo Saracino',
#  'Beth Grant',
#  'Bill Murray',
#  'Billy Crudup',
#  'Bob Balaban',
#  'Brad Garrett',
#  'Brad Pitt',
#  'Bradley Cooper',
#  'Brian Johnson',
#  "Brian d'Arcy James",
#  'Bruce Dern',
#  'Bruce Green',
#  'Bruce Greenwood',
#  'Bruce Willis',
#  'Bryce Dallas Howard',
#  'BÃ©rÃ©nice Bejo',
#  'Casey Affleck',
#  'Charlie Talbert',
#  'Charlize Theron',
#  'Chelan Simmons',
#  'Chiwetel Ejiofor',
# ...

# %% [markdown]
# ### Q9--> The movie studio wants to determine who it should approach to act in its next movie production. Find the top 3 actors who appeared in the most top-rated movies.

# %%
df11=(df[['actor_1_name','actor_2_name','actor_3_name']]).stack()
df44=df11.value_counts()
df44.sort_values(ascending = False)
#from below we can conclude that best actor to approach are Leonardo DiCaprio,Tom Hardy and either Jennifer Lawrence or Scarlett Johansson.
# Out:
# Leonardo DiCaprio     5
# Tom Hardy             5
# Jennifer Lawrence     4
# Scarlett Johansson    4
# Tom Hanks             3
#                      ..
# Katrina Bowden        1
# Tom Hughes            1
# Will Forte            1
# Bruce Dern            1
# Chelan Simmons        1
# Name: count, Length: 235, dtype: int64

# %% [markdown]
# #### Q.10-->Create a data visualization that shows each country and the number of top-rated movies produced in it. Find the country that produced the most top-rated movies.

# %%
df99=df['Country'].value_counts().to_frame()
df99.plot()
# Out:
# <Axes: xlabel='Country'>

# %%
#USA made the most top rated movie
df['Country'].max()
# Out:
# 'USA'
